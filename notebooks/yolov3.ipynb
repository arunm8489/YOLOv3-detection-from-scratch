# %%
import os
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
#mounting drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks/yolo')
# ! wget https://raw.githubusercontent.com/pjreddie/darknet/master/cfg/yolov3.cfg

# %% [markdown]
# # Defining model

# %% [markdown]
# We have yolo3.cfg file which contains information about different layers of our network.First we will process it required form

# %%
def parse_cfg(config_file):
    file = open(config_file,'r')
    file = file.read().split('\n')
    file =  [line for line in file if len(line)>0 and line[0] != '#']
    file = [line.lstrip().rstrip() for line in file]

    final_list = []
    element_dict = {}
    for line in file:

        if line[0] == '[':
            if len(element_dict) != 0: # appending the dict stored on previous iteration
                    final_list.append(element_dict)
                    element_dict = {} # again emptying dict
            element_dict['type'] = ''.join([i for i in line if i != '[' and i != ']'])
            
        else:
            val = line.split('=')
            element_dict[val[0].rstrip()] = val[1].lstrip()  #removing spaces on left and right side
        
    final_list.append(element_dict) # appending the values stored for last set
    return final_list

# %%
config_file = 'yolov3.cfg'
blocks = parse_cfg(config_file)
blocks[0:3]
# Out:
# [{'angle': '0',
#   'batch': '64',
#   'burn_in': '1000',
#   'channels': '3',
#   'decay': '0.0005',
#   'exposure': '1.5',
#   'height': '608',
#   'hue': '.1',
#   'learning_rate': '0.001',
#   'max_batches': '500200',
#   'momentum': '0.9',
#   'policy': 'steps',
#   'saturation': '1.5',
#   'scales': '.1,.1',
#   'steps': '400000,450000',
#   'subdivisions': '16',
#   'type': 'net',
#   'width': '608'},
#  {'activation': 'leaky',
#   'batch_normalize': '1',
#   'filters': '32',
#   'pad': '1',
#   'size': '3',
#   'stride': '1',
#   'type': 'convolutional'},
#  {'activation': 'leaky',
#   'batch_normalize': '1',
#   'filters': '64',
#   'pad': '1',
#   'size': '3',
#   'stride': '2',
#   'type': 'convolutional'}]

# %%
config_file = 'yolov3.cfg'
blocks = parse_cfg(config_file)
darknet_details = blocks[0]
channels = 3 
#list of filter numbers in each layer.It is useful while defining number of filters in routing layer
output_filters = []  
modulelist = nn.ModuleList()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6e8dcbdb4e8f> in <module>()
#       1 config_file = 'yolov3.cfg'
# ----> 2 blocks = parse_cfg(config_file)
#       3 darknet_details = blocks[0]
#       4 channels = 3
#       5 #list of filter numbers in each layer.It is useful while defining number of filters in routing layer
#
# NameError: name 'parse_cfg' is not defined
